# %% [markdown]
# <a href="https://colab.research.google.com/github/AICHUCKY/Ai-with-Chucky-Colab-Notebooks/blob/main/Kani_TTS_2_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🔴 **Brought to you by [AI With Chucky](https://youtube.com/@AIWithChucky)**
# *Subscribe for more AI tutorials, workflows, and optimization tips!*
#
# # 😻 Kani-TTS-2 Web UI on Google Colab
# This notebook launches the [Kani-TTS-2](https://huggingface.co/spaces/nineninesix/kanitts-2-en) web interface directly on a Google Colab GPU.
#
# Kani-TTS-2 is a fast and expressive Text-to-Speech model featuring zero-shot voice cloning. You can select built-in voices or upload a short audio clip to instantly clone a new voice. Run the enclosed cells below to get started.

# %%
# @title 📦 Step 1: Environment Setup & Dependencies
# Clone the repo
# !git clone https://huggingface.co/spaces/nineninesix/kanitts-2-en
# %cd kanitts-2-en

# Disable the auto-installer inside app.py that overrides the NumPy fix
# !sed -i 's/setup_dependencies()/# setup_dependencies()/g' app.py

# Install requirements first, followed by spaces and the fixed NumPy version
# !pip install -r requirements.txt
# !pip install spaces "numpy<2"

# Force the transformers upgrade separately to avoid dependency resolution blocks
# !pip install transformers==4.56.0

# %%
# @title 🚀 Step 2: Launch the Web Interface
# Change directory back into the cloned folder
# %cd /content/kanitts-2-en

# Run the application with a public shareable link
# !GRADIO_SHARE=True python app.py
